# %% [markdown]
# PRIMA PARTE

# %%
import pandas as pd
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/immobili.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat  medv
# ...

# %%
df.rename(columns={"medv": "price"}, inplace=True)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat price
# ...

# %%
df = df.drop(df[df.index == 506].index)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..  ...     ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273    21.0
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875   1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505   1  273    21.0
#
#           b lstat price
# 0     396.9  4.98  24.0
# ...

# %%
df = df.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    float64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio       b  lstat  price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
X = df.drop(columns='price')
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, 
                                                    random_state = 80
                                                    )

# %%
X_train.shape, X_test.shape
# Out:
# ((404, 13), (102, 13))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print('R2_score: ', r2score)
print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
# Out:
# R2_score:  0.784476567145691
# MAE:  2.9443166005600263
# MSE:  14.27928856741917
# RMSE:  3.7787945918532237

# %%
model.coef_
# Out:
# array([-1.13523534e-01,  4.81298576e-02,  4.18993522e-02,  3.29890395e+00,
#        -1.95022603e+01,  3.57778526e+00,  1.99893093e-03, -1.54239468e+00,
#         3.07707974e-01, -1.21881008e-02, -9.11991707e-01,  8.27996705e-03,
#        -5.51489395e-01])

# %%
model.intercept_
# Out:
# 38.76450845416562

# %%
y_pred = model.predict(X_test)

# %%
res_df = pd.DataFrame(data=list(zip(y_pred, y_test)),columns=['predicted', 'real'])
res_df
# Out:
#      predicted  real
# 0    18.599117  20.8
# 1    36.674949  43.1
# 2    25.334323  24.0
# 3    22.167010  16.1
# 4    23.727240  22.4
# ..         ...   ...
# 97   32.041717  31.1
# 98   35.303590  46.7
# 99    6.132290  13.8
# 100  20.554268  19.3
# 101  25.013501  23.8
#
# [102 rows x 2 columns]

# %%
res_df['error'] = res_df['real'] - res_df['predicted']
res_df
# Out:
#      predicted  real      error
# 0    18.599117  20.8   2.200883
# 1    36.674949  43.1   6.425051
# 2    25.334323  24.0  -1.334323
# 3    22.167010  16.1  -6.067010
# 4    23.727240  22.4  -1.327240
# ..         ...   ...        ...
# 97   32.041717  31.1  -0.941717
# 98   35.303590  46.7  11.396410
# 99    6.132290  13.8   7.667710
# 100  20.554268  19.3  -1.254268
# 101  25.013501  23.8  -1.213501
#
# [102 rows x 3 columns]

# %%
res_df['error'].mean()
# Out:
# -0.5993989357371025

# %%
y_test.shape
# Out:
# (102,)

# %%
y_pred.shape
# Out:
# (102,)

# %%
model.predict([[10,34,67.2,8,4.5,3.2,78,34,12,33,1,9,54]])[0]
# Out:
# c:\Users\ifoa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -87.45181571263468

# %%
import joblib


joblib.dump(model,'matriosca.pkl')
# Out:
# ['matriosca.pkl']

# %%
newmodel = joblib.load('matriosca.pkl')
newmodel
# Out:
# LinearRegression()

# %% [markdown]
# Inferenza

# %%
import pandas as pd
import joblib
new_model = joblib.load('matriosca.pkl')
new_model
# Out:
# LinearRegression()

# %%
newmodel.predict([[10,34,67.2,8,4.5,3.2,78,34,12,33,1,9,54]])[0]
# Out:
# c:\Users\ifoa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -87.45181571263468

# %%
df = pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/immobili.csv')

# %%
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat  medv
# ...

# %%
df.rename(columns={"medv": "price"}, inplace=True)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat price
# ...

# %%
df = df.drop(columns='price')
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat
# 0     396.9  4.98
# ...

# %%
df = df.drop(df[df.index == 506].index)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..  ...     ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273    21.0
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875   1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505   1  273    21.0
#
#           b lstat
# 0     396.9  4.98
# ...

# %%
df = df.astype(float)

# %%
y_pred=new_model.predict(df)
df['prediction']= y_pred

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio       b  lstat  prediction
# 0       15.3  396.90   4.98   29.867033
# ...
